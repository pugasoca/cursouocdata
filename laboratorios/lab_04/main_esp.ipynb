# %% [markdown]
# # Laboratorio: Programación en Python
#
# En este laboratorio, pondremos en práctica algunos de los conceptos que hemos aprendido recientemente. El objetivo es que implementes cada función utilizando tres enfoques diferentes en Python: **programación imperativa**, **programación orientada a objetos** y **programación funcional**.
#
# > **NOTA:** En este laboratorio deberías intentar escribir todas las funciones por ti mismo utilizando únicamente la sintaxis más básica de Python, sin utilizar funciones predefinidas como `len`, `count`, `sum`, `max`, `min`, `in`, etc. ¡Dale una oportunidad! 🧑🏻‍💻👩🏻‍💻
#
# La celda después de cada ejercicio contiene pruebas para verificar si tu función funciona como se espera.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Escribe una función que devuelva el mayor de dos números

# %%
#tu codigo aquí
def greater_imperativa(a, b):
    if a > b:
        return a
    else:
        return b

# %%
# Para testear tu función
test_greater(greater_imperativa)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.223s
#
# OK

# %%
class Comparador:
    @staticmethod
    def greater_poo(a, b):
        return a if a > b else b
# Uso en la prueba:
greater_poo = Comparador.greater_poo

# %%
test_greater(greater_poo)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.231s
#
# OK

# %%
greater_funcional = (lambda a, b: a if a > b else b)

# %%
test_greater(greater_funcional)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.169s
#
# OK

# %% [markdown]
# ## 2. Ahora escribe una función que devuelva el elemento más grande de una lista numerica

# %%
#tu codigo aquí

def greatest_imperativa(arr):
    if len(arr) == 0:
        return None  # Manejo de lista vacía
    max_num = arr[0]
    for num in arr:
        if num > max_num:
            max_num = num
    return max_num

# %%
# Para testear tu función
test_greatest(greatest_imperativa)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.207s
#
# OK

# %%
class ComparadorListas:
    @staticmethod
    def greatest_poo(arr):
        if len(arr) == 0:
            return None  # Manejo de lista vacía
        max_num = arr[0]
        for num in arr:
            if num > max_num:
                max_num = num
        return max_num
        
greatest_poo = ComparadorListas.greatest_poo

# %%
test_greatest(greatest_poo)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.190s
#
# OK

# %%
greatest_funcional = lambda arr: None if len(arr) == 0 else reduce(lambda a, b: a if a > b else b, arr)

# %%
test_greatest(greatest_funcional)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.199s
#
# OK

# %% [markdown]
# ## 3. Escribe una función que sume todos los elementos de una lista

# %%
def sum_imperativa(arr):
    total = 0
    for num in arr:
        total += num
    return total

# %%
# Para testear tu función
test_sum(sum_imperativa)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.179s
#
# OK

# %%
class Sumador:
    @staticmethod
    def sum_poo(arr):
        total = 0
        for num in arr:
            total += num
        return total

sum_poo = Sumador.sum_poo

# %%
test_sum(sum_poo)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.175s
#
# OK

# %%
sum_funcional = lambda arr: 0 if len(arr) == 0 else reduce(lambda a, b: a + b, arr)

# %%
test_sum(sum_funcional)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.188s
#
# OK

# %% [markdown]
# ## 4. Escribe otra función que multiplique todos los elementos de una lista

# %%
def mult_imperativa(arr):
    if len(arr) == 0:
        return 0  # Manejo de lista vacía
    product = 1
    for num in arr:
        product *= num
    return product

# %%
# Para testear tu función
test_mult(mult_imperativa)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.190s
#
# OK

# %%
class Multiplicador:
    @staticmethod
    def mult_poo(arr):
        if len(arr) == 0:
            return 0  # Manejo de lista vacía
        product = 1
        for num in arr:
            product *= num
        return product

mult_poo = Multiplicador.mult_poo

# %%
test_mult(mult_poo)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.207s
#
# OK

# %%
mult_funcional = lambda arr: 1 if len(arr) > 0 else 0 if len(arr) == 0 else reduce(lambda a, b: a * b, arr)

# %%
test_mult(mult_funcional)
# Out:
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 57528024325575728188282483412828160000000000000000 : Should be 57528024325575728188282483412828160000000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != -2015918121369600 : Should be -2015918121369600
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != -43545600000 : Should be -43545600000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 777600 : Should be 777600
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != -867041280000 : Should be -867041280000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 829440000 : Should be 829440000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 24670779464896855599148777340928000000 : Should be 24670779464896855599148777340928000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != -104509440000 : Should be -104509440000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != -195955200 : Should be -195955200
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 8467200000 : Should be 8467200000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 76559390460000000 : Should be 76559390460000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 22118400000 : Should be 22118400000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 385247952366059755929600000000 : Should be 385247952366059755929600000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 4762800000 : Should be 4762800000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 0 : Should be 0
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.220s
#
# FAILED (failures=100)

# %% [markdown]
# ## 5. Ahora combina esas dos ideas y escribe una función que reciba una lista y ya sea "+" o "*", y produzca el resultado acorde

# %%
def operaciones_imperativa(arr, op='+'):
    if len(arr) == 0:
        return 0 if op == "+" else 1  # Manejo de lista vacía
    if op == "+":
        total = 0
        for num in arr:
            total += num
        return total
    elif op == "*":
        product = 1
        for num in arr:
            product *= num
        return product
    else:
        raise ValueError("Operación no soportada")

# %%
# Para testear tu función
test_operations(operaciones_imperativa)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[45], line 2
#       1 # Para testear tu función
# ----> 2 test_operations(operaciones_imperativa)
#
# File ~/uoc/curso/laboratorios/lab_04/mod/testing.py:99, in test_operations(fn)
#      97         arr.append(random.randint(-10, 10))
#      98     op = random.choice(["+", "*"])
# ---> 99     suite.addTest(TestKnown((arr, op), ans(arr, op)))
#     101 def ans(arr, op):
#     102     if op == "+":
#
# UnboundLocalError: local variable 'ans' referenced before assignment

# %%
class Calculadora:
    @staticmethod
    def operaciones_poo(arr, op):
        if len(arr) == 0:
            return 0 if op == "+" else 1  # Manejo de lista vacía
        if op == "+":
            total = 0
            for num in arr:
                total += num
            return total
        elif op == "*":
            product = 1
            for num in arr:
                product *= num
            return product
        else:
            raise ValueError("Operación no soportada")

operaciones_poo = Calculadora.operaciones_poo

# %%
test_operations(operaciones_poo)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 test_operations(operaciones_poo)
#
# File ~/uoc/curso/laboratorios/lab_04/mod/testing.py:99, in test_operations(fn)
#      97         arr.append(random.randint(-10, 10))
#      98     op = random.choice(["+", "*"])
# ---> 99     suite.addTest(TestKnown((arr, op), ans(arr, op)))
#     101 def ans(arr, op):
#     102     if op == "+":
#
# UnboundLocalError: local variable 'ans' referenced before assignment

# %%
operaciones_funcional = lambda arr, op: (0 if len(arr) == 0 and op == "+" else 1 if len(arr) == 0 else
                                           reduce(lambda a, b: a + b, arr) if op == "+" else
                                           reduce(lambda a, b: a * b, arr))

# %%
test_operations(operaciones_funcional)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 test_operations(operaciones_funcional)
#
# File ~/uoc/curso/laboratorios/lab_04/mod/testing.py:99, in test_operations(fn)
#      97         arr.append(random.randint(-10, 10))
#      98     op = random.choice(["+", "*"])
# ---> 99     suite.addTest(TestKnown((arr, op), ans(arr, op)))
#     101 def ans(arr, op):
#     102     if op == "+":
#
# UnboundLocalError: local variable 'ans' referenced before assignment

# %% [markdown]
# ## 6. Escribe una función que devuelva el factorial de un número.

# %%
# Fórmula factorial
# n! = n * (n - 1) *...*1

# Este código define una función llamada "factorial" que toma una entrada "n". La función utiliza un bucle for para iterar a través del rango de números
# desde 1 hasta n+1. Para cada número en ese rango, multiplica el valor actual de x por el número en el rango. Al final del bucle,
# la función devuelve el valor final de x, que será el factorial del número de entrada "n".

# El factorial de un entero positivo n es el producto de todos los enteros positivos menores o iguales a n.
# Por ejemplo, el factorial de 6 (escrito "6!") es 6 * 5 * 4 * 3 * 2 * 1 = 720.

# Así que esta función toma una entrada de cualquier entero positivo y devuelve el factorial de ese número.

# %%
def factorial_imperativa(n):
    if n < 0:
        raise ValueError("El factorial no está definido para números negativos.")
    result = 1
    for i in range(1, n + 1):
        result *= i
    return result

# %%
# Para testear tu función
test_factorial(factorial_imperativa)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.197s
#
# OK

# %%
class CalculadoraFactorial:
    @staticmethod
    def factorial_poo(n):
        if n < 0:
            raise ValueError("El factorial no está definido para números negativos.")
        result = 1
        for i in range(1, n + 1):
            result *= i
        return result

factorial_poo = CalculadoraFactorial.factorial_poo

# %%
test_factorial(factorial_poo)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.202s
#
# OK

# %%
factorial_funcional = lambda n: 1 if n == 0 else (1 if n < 0 else n * factorial_funcional(n - 1))

# %%
test_factorial(factorial_funcional)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.230s
#
# OK

# %% [markdown]
# ## 7. Escribe una función que tome una lista y devuelva una lista de los valores únicos.
#
# `NOTE: No podemos usar set. 🤔`

# %%
def unique_imperativa(arr):
    unique_list = []
    for item in arr:
        if item not in unique_list:
            unique_list.append(item)
    return unique_list

# %%
# Para testear tu función 
test_unique(unique_imperativa)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.204s
#
# OK

# %%
class UniqueFinder:
    @staticmethod
    def unique_poo(arr):
        unique_list = []
        for item in arr:
            if item not in unique_list:
                unique_list.append(item)
        return unique_list

unique_poo = UniqueFinder.unique_poo

# %%
test_unique(unique_poo)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.243s
#
# OK

# %%
unique_funcional = lambda arr: [item for index, item in enumerate(arr) if item not in arr[:index]]

# %%
test_unique(unique_funcional)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.330s
#
# OK

# %% [markdown]
# ## 8. Escribe una función que devuelva la moda de una lista, es decir: el elemento que aparece más veces.
#
# `NOTE: No se debe usar count... 🧐`

# %%
def mode_counter(arr):
#tu codigo aquí

# %%
# Para testear tu función 
test_mode(mode_counter)

# %% [markdown]
# ## 9. Escribe una función que calcule la desviación estándar de una lista.
# `NOTE: no utilices librerías ni ninguna función ya construida. 😉`

# %%
def st_dev_imperativa(arr):
    if len(arr) == 0:
        raise ValueError("La lista no puede estar vacía.")
    
    mean = sum(arr) / len(arr)
    variance_sum = 0
    
    for num in arr:
        variance_sum += (num - mean) ** 2
    
    variance = variance_sum / len(arr)
    return variance ** 0.5  # Raíz cuadrada de la varianza

# %%
# Para testear tu función
test_stdev(st_dev_imperativa)
# Out:
# ..F.FFFF.FFFFFFF.F.F.FFFFFF.F..FF.FF...FF.FF.FF.FFFF.F...FF....FF..FFF.FFF...F.FFF.FFF.FF...F.F.FFF.
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError:
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 438.18382709375595 != 446.22456799168407 within 5 delta (8.040740897928117 difference) : Should be 446.22456799168407
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 530.0374295776601 != 535.1096736601783 within 5 delta (5.072244082518182 difference) : Should be 535.1096736601783
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 461.9693059592136 != 469.36128421607987 within 5 delta (7.391978256866253 difference) : Should be 469.36128421607987
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 628.7106799575045 != 642.8407741187278 within 5 delta (14.130094161223383 difference) : Should be 642.8407741187278
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.278s
#
# FAILED (failures=60)

# %%
class StatsCalculator:
    @staticmethod
    def st_dev_poo(arr):
        if len(arr) == 0:
            raise ValueError("La lista no puede estar vacía.")
        
        mean = sum(arr) / len(arr)
        variance_sum = 0
        
        for num in arr:
            variance_sum += (num - mean) ** 2
        
        variance = variance_sum / len(arr)
        return variance ** 0.5  # Raíz cuadrada de la varianza

# Uso en la prueba:
st_dev_poo = StatsCalculator.st_dev_poo

# %%
test_stdev(st_dev_poo)
# Out:
# .FFF..FFF...FFFF.FFFFFFFF.FFF.FFFFF.F..F.F..FFFF.F.FF.FFFF..F.....F..F.F..FFF.FF.F.F.F.FF.FF...FF.F.
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 580.2314735734094 != 587.264839139207 within 5 delta (7.033365565797567 difference) : Should be 587.264839139207
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 480.97112959095585 != 493.46596693826393 within 5 delta (12.494837347308078 difference) : Should be 493.46596693826393
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 590.1983930932687 != 596.8675131742624 within 5 delta (6.669120080993707 difference) : Should be 596.8675131742624
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 587.0833395976555 != 598.709880942733 within 5 delta (11.626541345077499 difference) : Should be 598.709880942733
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 584.1118551097712 != 600.1178831564766 within 5 delta (16.00602804670541 difference) : Should be 600.1178831564766
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 612.029710702027 != 621.2336814657768 within 5 delta (9.203970763749794 difference) : Should be 621.2336814657768
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 597.6157880690474 != 604.0766870590924 within 5 delta (6.460898990044939 difference) : Should be 604.0766870590924
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 622.7398021703992 != 628.936370733457 within 5 delta (6.196568563057781 difference) : Should be 628.936370733457
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 546.5812450972663 != 552.4904032636471 within 5 delta (5.909158166380735 difference) : Should be 552.4904032636471
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 514.6278534047685 != 527.9970369733447 within 5 delta (13.369183568576204 difference) : Should be 527.9970369733447
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 604.9765089562478 != 631.877355524189 within 5 delta (26.900846567941244 difference) : Should be 631.877355524189
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 504.5738480892395 != 514.185642199269 within 5 delta (9.61179411002945 difference) : Should be 514.185642199269
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 513.6749023517914 != 521.1742027190447 within 5 delta (7.4993003672533405 difference) : Should be 521.1742027190447
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 611.046246454491 != 622.2590394436324 within 5 delta (11.212792989141462 difference) : Should be 622.2590394436324
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 527.056423544956 != 537.924709725565 within 5 delta (10.868286180608948 difference) : Should be 537.924709725565
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 614.9416232456541 != 630.9167932461459 within 5 delta (15.975170000491744 difference) : Should be 630.9167932461459
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 590.492771168935 != 599.3728600061426 within 5 delta (8.880088837207609 difference) : Should be 599.3728600061426
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 574.792478784558 != 581.1439697067931 within 5 delta (6.35149092223503 difference) : Should be 581.1439697067931
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError:
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 586.822662463432 != 592.0389664917433 within 5 delta (5.216304028311242 difference) : Should be 592.0389664917433
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 581.1116797785087 != 588.5146747838132 within 5 delta (7.402995005304547 difference) : Should be 588.5146747838132
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 539.6836068990382 != 548.9096360110169 within 5 delta (9.226029111978733 difference) : Should be 548.9096360110169
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 606.5930886140403 != 615.197675677282 within 5 delta (8.604587063241638 difference) : Should be 615.197675677282
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 573.0264924578977 != 579.3584691266644 within 5 delta (6.3319766687667425 difference) : Should be 579.3584691266644
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 515.2518089175406 != 529.3709109910637 within 5 delta (14.119102073523095 difference) : Should be 529.3709109910637
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 655.4965886850806 != 674.5004251513943 within 5 delta (19.003836466313714 difference) : Should be 674.5004251513943
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 531.1123886476385 != 537.8784243293036 within 5 delta (6.76603568166513 difference) : Should be 537.8784243293036
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 553.2949348204438 != 561.3726604186796 within 5 delta (8.077725598235816 difference) : Should be 561.3726604186796
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 524.4339424188117 != 532.8254183231974 within 5 delta (8.39147590438563 difference) : Should be 532.8254183231974
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 511.30408723602477 != 516.8318596389307 within 5 delta (5.527772402905953 difference) : Should be 516.8318596389307
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 478.6716227692682 != 484.33657288718337 within 5 delta (5.6649501179151684 difference) : Should be 484.33657288718337
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 526.7173830433169 != 532.0649047410878 within 5 delta (5.347521697770958 difference) : Should be 532.0649047410878
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 547.3470156633317 != 566.557986777128 within 5 delta (19.21097111379629 difference) : Should be 566.557986777128
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 174, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 628.0694482570459 != 647.3991688468014 within 5 delta (19.32972058975554 difference) : Should be 647.3991688468014
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.197s
#
# FAILED (failures=58)

# %% [markdown]
# ## 10. Escribe una función para verificar si una cadena es un pangrama, es decir: si contiene todas las letras del alfabeto al menos una vez. Ten en cuenta que las cadenas pueden contener caracteres que no son letras.

# %%
def is_pangram_imperativa(s):
    alphabet = set(string.ascii_lowercase)
    s_lower = set(s.lower())  # Convertimos a minúsculas y a un conjunto para eliminar duplicados
    return alphabet.issubset(s_lower)  # Verificamos si el alfabeto está contenido en la cadena

# %%
# Para testear tu función
test_pangram(is_pangram_imperativa)
# Out:
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2372144315.py", line 2, in is_pangram_imperativa
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ----------------------------------------------------------------------
# Ran 30 tests in 0.131s
#
# FAILED (errors=30)

# %%
class PangramChecker:
    @staticmethod
    def is_pangram_poo(s):
        alphabet = set(string.ascii_lowercase)
        s_lower = set(s.lower())
        return alphabet.issubset(s_lower)

# Uso en la prueba:
is_pangram_poo = PangramChecker.is_pangram_poo

# %%
test_pangram(is_pangram_poo)
# Out:
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/2033784862.py", line 4, in is_pangram_poo
#     alphabet = set(string.ascii_lowercase)
# NameError: name 'string' is not defined
#
# ----------------------------------------------------------------------
# Ran 30 tests in 0.155s
#
# FAILED (errors=30)

# %%
is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))

# %%
# Test para la función funcional
test_pangram(is_pangram_funcional)
# Out:
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/ubuntu/uoc/curso/laboratorios/lab_04/mod/testing.py", line 211, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_917699/4011542904.py", line 1, in <lambda>
#     is_pangram_funcional = lambda s: set(string.ascii_lowercase).issubset(set(s.lower()))
# NameError: name 'string' is not defined
#
# ----------------------------------------------------------------------
# Ran 30 tests in 0.147s
#
# FAILED (errors=30)

# %% [markdown]
# ## 11. Escribe una función que reciba una cadena de palabras separadas por comas y devuelva una cadena de palabras separadas por comas ordenadas alfabéticamente.
#
# `NOTA: Puedes usar sorted pero no split y definitivamente no join! 🤪`

# %%
def sort_words_imperativa(s):
    words = []
    current_word = ''
    
    for char in s:
        if char == ',':
            if current_word:  # Asegúrate de no añadir cadenas vacías
                words.append(current_word)
                current_word = ''
        else:
            current_word += char

    # Agrega la última palabra si hay alguna
    if current_word:
        words.append(current_word)
    
    # Ordena las palabras
    sorted_words = sorted(words)
    
    # Construye la cadena ordenada sin usar join
    result = ''
    for word in sorted_words:
        result += word + ','  # Agrega la coma después de cada palabra

    return result[:-1] if result else result  # Elimina la última coma

# %%
# Para testear tu función 
test_alpha(sort_words_imperativa)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.205s
#
# OK

# %%
class WordSorter:
    @staticmethod
    def sort_words_poo(s):
        words = []
        current_word = ''
        
        for char in s:
            if char == ',':
                if current_word:
                    words.append(current_word)
                    current_word = ''
            else:
                current_word += char

        if current_word:
            words.append(current_word)
        
        sorted_words = sorted(words)
        
        result = ''
        for word in sorted_words:
            result += word + ','

        return result[:-1] if result else result

sort_words_poo = WordSorter.sort_words_poo

# %%
test_alpha(sort_words_poo)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.176s
#
# OK

# %%
def sort_words_funcional(s):
    words = []
    current_word = ''
    
    for char in s:
        if char == ',':
            if current_word:
                words.append(current_word)
                current_word = ''
        else:
            current_word += char

    if current_word:
        words.append(current_word)

    sorted_words = sorted(words)
    
    result = ''
    for word in sorted_words:
        result += word + ','
    
    return result[:-1] if result else result

# %%
# Test para la función funcional
test_alpha(sort_words_funcional)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.178s
#
# OK

# %% [markdown]
# ## 12. Escribe una función para verificar si una contraseña dada es fuerte (al menos 8 caracteres, al menos una minúscula, al menos una mayúscula, al menos un número y al menos un carácter especial). Debería devolver True si es fuerte y False si no lo es. Se permit el uso de regex

# %%
import re 

def is_strong_password_imperativa(password):
    pattern = r'^(?=.*[a-z])(?=.*[A-Z])(?=.*\d)(?=.*[#@!$%&()^*[\]{}]).{8,}$'
    return bool(re.match(pattern, password))

# %%
# Para testear tu función
test_pass(is_strong_password_imperativa)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.208s
#
# OK

# %%
class PasswordValidator:
    @staticmethod
    def is_strong_password_poo(password):
        pattern = r'^(?=.*[a-z])(?=.*[A-Z])(?=.*\d)(?=.*[#@!$%&()^*[\]{}]).{8,}$'
        return bool(re.match(pattern, password))

is_strong_password_poo = PasswordValidator.is_strong_password_poo

# %%
test_pass(is_strong_password_poo)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.181s
#
# OK

# %%
def is_strong_password_funcional(password):
    pattern = r'^(?=.*[a-z])(?=.*[A-Z])(?=.*\d)(?=.*[#@!$%&()^*[\]{}]).{8,}$'
    return bool(re.match(pattern, password))

# %%
test_pass(is_strong_password_funcional)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.214s
#
# OK
